# %%
import scanpy as sc
adata = sc.read_csv('data_mpp.csv')
sc.tl.pca(adata, svd_solver='arpack')
sc.tl.tsne(adata, n_pcs=50)
sc.pl.tsne(adata)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-81-c94ff0bcf2e3> in <module>
#       1 import scanpy as sc
# ----> 2 adata = sc.read_csv('marrow_sample_scseq_counts.h5ad')
#       3 sc.tl.pca(adata, svd_solver='arpack')
#       4 sc.tl.tsne(adata, n_pcs=50)
#       5 sc.pl.tsne(adata)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/anndata/_io/read.py in read_csv(filename, delimiter, first_column_names, dtype)
#      46         Numpy data type.
#      47     """
# ---> 48     return read_text(filename, delimiter, first_column_names, dtype)
#      49
#      50
#
# ~/opt/anaconda3/lib/python3.7/site-packages/anndata/_io/read.py in read_text(filename, delimiter, first_column_names, dtype)
#     322             return _read_text(f, delimiter, first_column_names, dtype)
#     323     else:
# --> 324         with filename.open() as f:
# ...

# %%
import pyMuTrans as pm
par = {"choice_distance":"cosine","perplex":800.0,"K_cluster":10.0,"trials":10,"weight_scale":True,"initial":"pca"} 
adata = pm.dynamical_analysis(adata,par)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-db54dfd2301e> in <module>
#       1 import pyMuTrans as pm
#       2 par = {"choice_distance":"cosine","perplex":800.0,"K_cluster":10.0,"trials":10,"weight_scale":True,"initial":"pca"}
# ----> 3 adata = pm.dynamical_analysis(adata,par)
#
# ~/Documents/GitHub/pyMuTrans/pyMuTrans.py in dynamical_analysis(sc_object, par)
#      30     par['perplex'] = float(par['perplex'])
#      31     par['K_cluster'] = float(par['K_cluster'])
# ---> 32
#      33     out = eng.DynamicalAnalysis(data_convert,par)
#      34     perm = np.asarray(out['perm_class']).ravel()
#
# TypeError: 'NoneType' object is not subscriptable

# %%
import matplotlib.pyplot as plt
fig = plt.figure(dpi=100)
pm.infer_lineage(adata,si=0,sf=5,method = "MPPT",flux_fraction = 0.7,size_state = 0.2,size_text=25,alpha_point = 0.7)

# %%
import importlib
import pyMuTrans as pm
importlib.reload(pm)

par = {"choice_distance":"cosine","perplex":200.0,"K_cluster":10.0,"trials":10,"weight_scale":True,"initial":"pca","reduce_large_scale":True,"reduce_num_meta_cell":500.0} 
adata = pm.dynamical_analysis(adata,par)

# %%
import matplotlib.pyplot as plt
fig = plt.figure(dpi=100)
pm.infer_lineage(adata,si=3,sf=4,method = "MPPT",flux_fraction = 0.7,size_state = 0.2,size_text=16,alpha_point = 0.7)
